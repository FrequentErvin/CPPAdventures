# %% [markdown]
# <a href="https://colab.research.google.com/github/FrequentErvin/CPPAdventures/blob/master/yolocow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12270, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 12270 (delta 5), reused 9 (delta 1), pack-reused 12250
# Receiving objects: 100% (12270/12270), 12.04 MiB | 29.08 MiB/s, done.
# Resolving deltas: 100% (8491/8491), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 9.2 MB/s
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data /content/drive/MyDrive/Cows-1/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/Cows-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/Cows-1"

# %%
directory = '/content/drive/MyDrive/exported_sorted'
i = 0
for dir in os.listdir(directory):
  i += 1
  print(i)
  print(dir)
# Out:
# 1
# .DS_Store
# 2
# 00110704
# 3
# 00110715
# 4
# 00052787
# 5
# 00052778
# 6
# 00110724
# 7
# 00110709
# 8
# 00110718
# 9
# 00110708
# 10
# 0010727
# 11
# 00052795
# 12
# 00111045
# 13
# 002057
# 14
# 00111023
# 15
# 00111029
# 16
# 00111041
# 17
# 00110732
# 18
# 00110744
# 19
# 00110731
# 20
# 002038
# 21
# 00110725
# 22
# 002058
# 23
# 0859
# 24
# 002069
# 25
# 0706
# 26
# 002059
# 27
# 0844
# 28
# 0858
# 29
# 002076
# 30
# 0728
# 31
# 002071
# 32
# 0871
# 33
# 0894
# 34
# 0892
# 35
# 0885
# 36
# 3364
# 37
# 0899
# 38
# 0965
# 39
# 0986
# 40
# 0872
# 41
# 1271
# 42
# 3709
# 43
# 3831
# 44
# 3876
# 45
# 3821
# 46
# 3884
# 47
# 3717
# 48
# 3376
# 49
# 3883
# 50
# 3588
# 51
# 3794
# 52
# 3890
# 53
# 6548
# 54
# 3889
# 55
# 3896
# 56
# 3973
# 57
# 5219
# 58
# 4054
# 59
# 6567
# 60
# 8558
# 61
# 6281
# 62
# 8709
# 63
# 8561
# 64
# 8720
# 65
# 8683
# 66
# 8727
# 67
# 8783
# 68
# 9167
# 69
# 999999-1
# 70
# 8771

# %%
print(5)

# %%
import os
import subprocess
# script = "!python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source"
# directory = '/content/drive/MyDrive/exported_sorted'
# i = 0
# for dirname in os.listdir(directory):
#   if dirname != ".DS_Store":
#     i+=1
#     print(i)
#     f = os.path.join(directory, dirname)
#     this = script + f + " --save-crop"

# len = "python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source"
len = "!bash python --version"
# stream = os.system(len)
stream = subprocess.call(["python --version"])
print(stream)

# %%
import os
os.system("python --version")

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0706 --save-crop
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0706 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0706, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0706/IMG_8787.jpeg: 416x320 Done. (0.015s)
# image 2/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0706/IMG_8788.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0728 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0728, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0728/IMG_8417.jpeg: 416x320 Done. (0.014s)
# image 2/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0728/IMG_8418.jpeg: 416x320 Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0844 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0844, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/30 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0844/IMG_7973.jpeg: 416x320 Done. (0.015s)
# image 2/30 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0844/IMG_7974.jpeg: 416x320 Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0858 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0858, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/22 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0858/IMG_8556.jpeg: 416x320 Done. (0.014s)
# image 2/22 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0858/IMG_8557.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0859 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0859, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/31 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0859/IMG_7480.jpeg: 416x320 Done. (0.014s)
# image 2/31 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0859/IMG_7481.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0892 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0892, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0892/IMG_7511.jpeg: 416x320 1 muzzles, Done. (0.015s)
# image 2/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0892/IMG_7512.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0894 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0894, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0894/IMG_8070.jpeg: 416x320 1 muzzles, Done. (0.016s)
# image 2/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0894/IMG_8071.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0899 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0899, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/26 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0899/IMG_7327.jpeg: 416x320 1 muzzles, Done. (0.015s)
# image 2/26 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0899/IMG_7328.jpeg: 416x320 1 muzzles, Done. (0.011s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0965 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0965, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/17 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0965/IMG_8437.jpeg: 416x320 Done. (0.015s)
# image 2/17 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0965/IMG_8438.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0986 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0986, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/23 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0986/IMG_8303.jpeg: 416x320 Done. (0.015s)
# image 2/23 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0986/IMG_8304.jpeg: 416x320 Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/1271 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/1271, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/23 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/1271/IMG_7903.jpeg: 416x320 Done. (0.015s)
# image 2/23 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/1271/IMG_7904.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3364 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3364, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/32 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3364/IMG_8472.jpeg: 416x320 Done. (0.015s)
# image 2/32 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3364/IMG_8473.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3376 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3376, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3376/IMG_8657.jpeg: 416x320 1 muzzles, Done. (0.015s)
# image 2/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3376/IMG_8658.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3588 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3588, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/18 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3588/IMG_8454.jpeg: 416x320 1 muzzles, Done. (0.015s)
# image 2/18 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3588/IMG_8455.jpeg: 416x320 2 muzzless, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3709 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3709, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/21 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3709/IMG_8876.jpeg: 416x320 Done. (0.015s)
# image 2/21 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3709/IMG_8877.jpeg: 416x320 2 muzzless, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3794 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3794, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3794/IMG_8245.jpeg: 416x320 1 muzzles, Done. (0.015s)
# image 2/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3794/IMG_8246.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3821 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3821, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/26 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3821/IMG_8326.jpeg: 416x320 Done. (0.015s)
# image 2/26 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3821/IMG_8327.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3831 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3831, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/30 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3831/IMG_8352.jpeg: 416x320 Done. (0.015s)
# image 2/30 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3831/IMG_8353.jpeg: 416x320 1 muzzles, Done. (0.011s)
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3876 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3876, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/36 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3876/IMG_8815.jpeg: 416x320 Done. (0.015s)
# image 2/36 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3876/IMG_8816.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/3717 --save-crop
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/3717, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3717/IMG_8637.jpeg: 416x320 1 muzzles, Done. (0.250s)
# image 2/20 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/3717/IMG_8638.jpeg: 416x320 1 muzzles, Done. (0.141s)
# ...
